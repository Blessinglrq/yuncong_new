# %%
# %matplotlib inline
from detector import Detector
from utils import draw_bounding_boxes, change_coordinate_inv

# %%
# state_file = "./epoch_41.pth.tar"
state_file = "/home/lrq/tiny object detection 相关论文代码/SFD/dataset/logs_voc/models/epoch_662.pth.tar"
detector = Detector(state_file)

# %%
test_image ="/home/public/Dataset/yuncong/yuncong_data_new/Data/test/our/test/23/2260.jpg"

bboxes = detector.infer(test_image)
draw_bounding_boxes(test_image, bboxes)
